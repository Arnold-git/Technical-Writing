# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('train.csv')

data.head(5)
# Out:
#     EmployeeNo                               Division        Qualification  \
# 0  YAK/S/00001         Commercial Sales and Marketing     MSc, MBA and PhD
# 1  YAK/S/00002  Customer Support and Field Operations  First Degree or HND
# 2  YAK/S/00003         Commercial Sales and Marketing  First Degree or HND
# 3  YAK/S/00004         Commercial Sales and Marketing  First Degree or HND
# 4  YAK/S/00006               Information and Strategy  First Degree or HND
#
#    Gender   Channel_of_Recruitment  Trainings_Attended  Year_of_birth  \
# 0  Female  Direct Internal process                   2           1986
# 1    Male        Agency and others                   2           1991
# 2    Male  Direct Internal process                   2           1987
# 3    Male        Agency and others                   3           1982
# 4    Male  Direct Internal process                   3           1990
#
#    Last_performance_score  Year_of_recruitment  Targets_met  Previous_Award  \
# 0                    12.5                 2011            1               0
# 1                    12.5                 2015            0               0
# 2                     7.5                 2012            0               0
# 3                     2.5                 2009            0               0
# 4                     7.5                 2012            0               0
#
#    Training_score_average State_Of_Origin Foreign_schooled Marital_Status  \
# 0                      41         ANAMBRA               No        Married
# 1                      52         ANAMBRA              Yes        Married
# 2                      42         KATSINA              Yes        Married
# 3                      42           NIGER              Yes         Single
# 4                      77       AKWA IBOM              Yes        Married
#
#   Past_Disciplinary_Action Previous_IntraDepartmental_Movement  \
# 0                       No                                  No
# 1                       No                                  No
# 2                       No                                  No
# 3                       No                                  No
# 4                       No                                  No
#
#   No_of_previous_employers  Promoted_or_Not
# 0                        0                0
# 1                        0                0
# 2                        0                0
# 3                        1                0
# 4                        1                0

# %% [markdown]
# ## Pandas isin Syntax
#
# ### TODO

# %%
data.columns
# Out:
# Index(['EmployeeNo', 'Division', 'Qualification', 'Gender',
#        'Channel_of_Recruitment', 'Trainings_Attended', 'Year_of_birth',
#        'Last_performance_score', 'Year_of_recruitment', 'Targets_met',
#        'Previous_Award', 'Training_score_average', 'State_Of_Origin',
#        'Foreign_schooled', 'Marital_Status', 'Past_Disciplinary_Action',
#        'Previous_IntraDepartmental_Movement', 'No_of_previous_employers',
#        'Promoted_or_Not'],
#       dtype='object')

# %%
def num_unique(df, var):

    return df[var].unique()

# %%
for var in ['Division', 'Qualification', 'Channel_of_Recruitment', 'Gender']:

    print(num_unique(data, var))
# Out:
# ['Commercial Sales and Marketing' 'Customer Support and Field Operations'
#  'Information and Strategy' 'Information Technology and Solution Support'
#  'Sourcing and Purchasing' 'Business Finance Operations'
#  'People/HR Management' 'Research and Innovation'
#  'Regulatory and Legal services']
# ['MSc, MBA and PhD' 'First Degree or HND' nan 'Non-University Education']
# ['Direct Internal process' 'Agency and others'
#  'Referral and Special candidates']
# ['Female' 'Male']

# %% [markdown]
# ### Filtering a Single Column with Pandas Isin
#
# 1. Filter dataframe to get only those with `'MSc, MBA and PhD` qualification
# 2. Filter dataframe to get only those employed through `Referral and Special candidates`
# 3. Filter dataframe to get only those in `Customer Support and Field Operations` division

# %% [markdown]
# #### 1. Filter dataframe to get only those with `MBA and PhD` qualification

# %%
data_1 = data[data['Qualification'].isin(['MSc, MBA and PhD'])]

data_1
# Out:
#         EmployeeNo                                     Division  \
# 0      YAK/S/00001               Commercial Sales and Marketing
# 6      YAK/S/00008        Customer Support and Field Operations
# 8      YAK/S/00010               Commercial Sales and Marketing
# 11     YAK/S/00014  Information Technology and Solution Support
# 18     YAK/S/00025                  Business Finance Operations
# ...            ...                                          ...
# 38287  YAK/S/54769  Information Technology and Solution Support
# 38300  YAK/S/54790               Commercial Sales and Marketing
# 38304  YAK/S/54796                      Sourcing and Purchasing
# 38305  YAK/S/54799               Commercial Sales and Marketing
# 38308  YAK/S/54805        Customer Support and Field Operations
#
#           Qualification  Gender   Channel_of_Recruitment  Trainings_Attended  \
# 0      MSc, MBA and PhD  Female  Direct Internal process                   2
# 6      MSc, MBA and PhD    Male  Direct Internal process                   2
# 8      MSc, MBA and PhD    Male  Direct Internal process                   2
# 11     MSc, MBA and PhD    Male        Agency and others                   3
# 18     MSc, MBA and PhD    Male  Direct Internal process                   3
# ...                 ...     ...                      ...                 ...
# 38287  MSc, MBA and PhD  Female  Direct Internal process                   2
# 38300  MSc, MBA and PhD    Male        Agency and others                   4
# 38304  MSc, MBA and PhD    Male        Agency and others                   2
# 38305  MSc, MBA and PhD  Female        Agency and others                   3
# 38308  MSc, MBA and PhD  Female        Agency and others                   2
#
#        Year_of_birth  Last_performance_score  Year_of_recruitment  \
# 0               1986                    12.5                 2011
# 6               1988                     7.5                 2013
# 8               1989                    12.5                 2014
# 11              1982                     7.5                 2003
# 18              1982                    12.5                 2012
# ...              ...                     ...                  ...
# 38287           1980                    12.5                 2013
# 38300           1990                     7.5                 2010
# 38304           1986                     7.5                 2012
# 38305           1981                    12.5                 2015
# 38308           1984                     5.0                 2013
#
#        Targets_met  Previous_Award  Training_score_average State_Of_Origin  \
# 0                1               0                      41         ANAMBRA
# 6                0               0                      55             OYO
# 8                1               0                      46            ONDO
# 11               0               0                      72             EDO
# 18               0               0                      51         PLATEAU
# ...            ...             ...                     ...             ...
# 38287            1               0                      71         BAYELSA
# 38300            0               0                      42             OYO
# 38304            0               0                      62             FCT
# 38305            1               0                      43             FCT
# 38308            0               0                      48             IMO
#
#       Foreign_schooled Marital_Status Past_Disciplinary_Action  \
# 0                   No        Married                       No
# 6                   No         Single                       No
# 8                  Yes        Married                       No
# 11                 Yes        Married                       No
# 18                 Yes         Single                       No
# ...                ...            ...                      ...
# 38287              Yes         Single                       No
# 38300              Yes         Single                       No
# 38304              Yes        Married                       No
# 38305              Yes        Married                       No
# 38308              Yes        Married                       No
#
#       Previous_IntraDepartmental_Movement No_of_previous_employers  \
# 0                                      No                        0
# 6                                      No                        1
# 8                                      No                        0
# 11                                     No                        0
# 18                                    Yes                        0
# ...                                   ...                      ...
# 38287                                  No                        1
# 38300                                  No                        1
# 38304                                 Yes                        4
# 38305                                  No                        1
# 38308                                  No                        1
#
#        Promoted_or_Not
# 0                    0
# 6                    0
# 8                    0
# 11                   0
# 18                   0
# ...                ...
# 38287                0
# 38300                0
# 38304                0
# 38305                0
# 38308                0
#
# [10469 rows x 19 columns]

# %% [markdown]
# #### 2. Filter dataframe to get only those employed through `Referral and Special candidates`

# %%
data_2 = data[data['Channel_of_Recruitment'].isin(['Referral and Special candidates'])]

data_2
# Out:
#         EmployeeNo                                     Division  \
# 53     YAK/S/00081  Information Technology and Solution Support
# 77     YAK/S/00115               Commercial Sales and Marketing
# 200    YAK/S/00282  Information Technology and Solution Support
# 221    YAK/S/00310                      Sourcing and Purchasing
# 278    YAK/S/00388        Customer Support and Field Operations
# ...            ...                                          ...
# 38149  YAK/S/54570  Information Technology and Solution Support
# 38172  YAK/S/54604                         People/HR Management
# 38186  YAK/S/54622  Information Technology and Solution Support
# 38190  YAK/S/54627        Customer Support and Field Operations
# 38260  YAK/S/54728  Information Technology and Solution Support
#
#              Qualification  Gender           Channel_of_Recruitment  \
# 53     First Degree or HND    Male  Referral and Special candidates
# 77     First Degree or HND    Male  Referral and Special candidates
# 200    First Degree or HND    Male  Referral and Special candidates
# 221    First Degree or HND  Female  Referral and Special candidates
# 278       MSc, MBA and PhD  Female  Referral and Special candidates
# ...                    ...     ...                              ...
# 38149  First Degree or HND    Male  Referral and Special candidates
# 38172  First Degree or HND    Male  Referral and Special candidates
# 38186  First Degree or HND  Female  Referral and Special candidates
# 38190  First Degree or HND    Male  Referral and Special candidates
# 38260     MSc, MBA and PhD    Male  Referral and Special candidates
#
#        Trainings_Attended  Year_of_birth  Last_performance_score  \
# 53                      2           1974                     7.5
# 77                      2           1987                    12.5
# 200                     3           1992                    10.0
# 221                     2           1988                     7.5
# 278                     2           1989                    10.0
# ...                   ...            ...                     ...
# 38149                   2           1996                    10.0
# 38172                   2           1995                    12.5
# 38186                   2           1972                     7.5
# 38190                   2           1990                    12.5
# 38260                   2           1983                    10.0
#
#        Year_of_recruitment  Targets_met  Previous_Award  \
# 53                    2012            0               0
# 77                    2014            0               0
# 200                   2013            0               0
# 221                   2016            1               0
# 278                   2012            1               0
# ...                    ...          ...             ...
# 38149                 2015            1               0
# 38172                 2017            0               0
# 38186                 2006            0               0
# 38190                 2017            1               0
# 38260                 2007            1               0
#
#        Training_score_average State_Of_Origin Foreign_schooled Marital_Status  \
# 53                         71           LAGOS              Yes        Married
# 77                         41             OYO              Yes        Married
# 200                        67             OYO              Yes         Single
# 221                        59           BENUE              Yes        Married
# 278                        51          RIVERS              Yes        Married
# ...                       ...             ...              ...            ...
# 38149                      69             OYO               No         Single
# 38172                      42           LAGOS              Yes        Married
# 38186                      72         ANAMBRA              Yes        Married
# 38190                      51           LAGOS               No        Married
# 38260                      69             FCT              Yes        Married
#
#       Past_Disciplinary_Action Previous_IntraDepartmental_Movement  \
# 53                          No                                  No
# 77                          No                                  No
# 200                         No                                  No
# 221                         No                                  No
# 278                         No                                  No
# ...                        ...                                 ...
# 38149                       No                                 Yes
# 38172                       No                                  No
# 38186                       No                                  No
# 38190                       No                                  No
# 38260                       No                                  No
#
#       No_of_previous_employers  Promoted_or_Not
# 53                           0                0
# 77                           0                0
# 200                          0                0
# 221                          1                0
# 278                          3                0
# ...                        ...              ...
# 38149                        0                0
# 38172                        3                0
# 38186                        0                0
# 38190                        1                0
# 38260                        0                0
#
# [808 rows x 19 columns]

# %% [markdown]
# #### 3. Filter dataframe to get only those in `Customer Support and Field Operations` division

# %%
data_3 = data[data['Division'].isin(['Customer Support and Field Operations'])]

data_3
# Out:
#         EmployeeNo                               Division  \
# 1      YAK/S/00002  Customer Support and Field Operations
# 5      YAK/S/00007  Customer Support and Field Operations
# 6      YAK/S/00008  Customer Support and Field Operations
# 13     YAK/S/00020  Customer Support and Field Operations
# 15     YAK/S/00022  Customer Support and Field Operations
# ...            ...                                    ...
# 38288  YAK/S/54770  Customer Support and Field Operations
# 38292  YAK/S/54775  Customer Support and Field Operations
# 38295  YAK/S/54781  Customer Support and Field Operations
# 38296  YAK/S/54783  Customer Support and Field Operations
# 38308  YAK/S/54805  Customer Support and Field Operations
#
#                   Qualification  Gender   Channel_of_Recruitment  \
# 1           First Degree or HND    Male        Agency and others
# 5           First Degree or HND  Female        Agency and others
# 6              MSc, MBA and PhD    Male  Direct Internal process
# 13          First Degree or HND    Male        Agency and others
# 15                          NaN    Male  Direct Internal process
# ...                         ...     ...                      ...
# 38288       First Degree or HND    Male        Agency and others
# 38292       First Degree or HND    Male  Direct Internal process
# 38295       First Degree or HND  Female  Direct Internal process
# 38296  Non-University Education    Male  Direct Internal process
# 38308          MSc, MBA and PhD  Female        Agency and others
#
#        Trainings_Attended  Year_of_birth  Last_performance_score  \
# 1                       2           1991                    12.5
# 5                       2           1990                     7.5
# 6                       2           1988                     7.5
# 13                      2           1984                     7.5
# 15                      2           1980                    10.0
# ...                   ...            ...                     ...
# 38288                   2           1991                     2.5
# 38292                   2           1987                     2.5
# 38295                   2           1982                    12.5
# 38296                   3           1995                     7.5
# 38308                   2           1984                     5.0
#
#        Year_of_recruitment  Targets_met  Previous_Award  \
# 1                     2015            0               0
# 5                     2014            0               0
# 6                     2013            0               0
# 13                    2010            0               0
# 15                    2008            0               0
# ...                    ...          ...             ...
# 38288                 2017            0               0
# 38292                 2014            0               0
# 38295                 2012            0               0
# 38296                 2017            0               0
# 38308                 2013            0               0
#
#        Training_score_average State_Of_Origin Foreign_schooled Marital_Status  \
# 1                          52         ANAMBRA              Yes        Married
# 5                          51           ENUGU              Yes        Married
# 6                          55             OYO               No         Single
# 13                         51          BAUCHI              Yes        Married
# 15                         49          RIVERS              Yes        Married
# ...                       ...             ...              ...            ...
# 38288                      52            YOBE              Yes        Married
# 38292                      49           LAGOS              Yes        Married
# 38295                      52          RIVERS              Yes        Married
# 38296                      52          RIVERS              Yes        Married
# 38308                      48             IMO              Yes        Married
#
#       Past_Disciplinary_Action Previous_IntraDepartmental_Movement  \
# 1                           No                                  No
# 5                           No                                 Yes
# 6                           No                                  No
# 13                          No                                  No
# 15                          No                                  No
# ...                        ...                                 ...
# 38288                       No                                  No
# 38292                       No                                  No
# 38295                       No                                  No
# 38296                       No                                 Yes
# 38308                       No                                  No
#
#       No_of_previous_employers  Promoted_or_Not
# 1                            0                0
# 5                            1                0
# 6                            1                0
# 13                           1                0
# 15                           1                0
# ...                        ...              ...
# 38288                        0                0
# 38292                        1                0
# 38295                        1                0
# 38296                        0                0
# 38308                        1                0
#
# [7973 rows x 19 columns]

# %% [markdown]
# ### Filtering Multiple Columns with Pandas Isin
#
# In this section we would like at the following used cases on filtering multiple columns with pandas isin method
#
# 1. filter dataframe to include `female` in `Information Technology and Solution Support` division with `MSc MBA and PhD` Qualification
# 2. filter dataframe to include `male` employed through `Direct Internal process` with `First Degree or HND` Qualification
# 3. filter dataframe to include those in `Customer Support and Field Operations` with `Non-University Education` and employed throgh `Direct Internal process` and are `married`

# %% [markdown]
# #### 1. filter dataframe to include `female` in `Information Technology and Solution Support division` with `MSc MBA and PhD` Qualification

# %%
data_4 = data[data[['Gender', 'Division', 'Qualification']].
                isin(['Female', 'Information Technology and Solution Support', 'MSc, MBA and PhD']).all(axis=1)]

# %%
data_4.head(6)
# Out:
#       EmployeeNo                                     Division  \
# 189  YAK/S/00262  Information Technology and Solution Support
# 299  YAK/S/00422  Information Technology and Solution Support
# 317  YAK/S/00452  Information Technology and Solution Support
# 464  YAK/S/00647  Information Technology and Solution Support
# 496  YAK/S/00701  Information Technology and Solution Support
# 529  YAK/S/00753  Information Technology and Solution Support
#
#         Qualification  Gender   Channel_of_Recruitment  Trainings_Attended  \
# 189  MSc, MBA and PhD  Female        Agency and others                   3
# 299  MSc, MBA and PhD  Female  Direct Internal process                   2
# 317  MSc, MBA and PhD  Female  Direct Internal process                   2
# 464  MSc, MBA and PhD  Female  Direct Internal process                   2
# 496  MSc, MBA and PhD  Female        Agency and others                   2
# 529  MSc, MBA and PhD  Female        Agency and others                   2
#
#      Year_of_birth  Last_performance_score  Year_of_recruitment  Targets_met  \
# 189           1983                     7.5                 2009            0
# 299           1991                     7.5                 2017            0
# 317           1980                     2.5                 2008            0
# 464           1965                     5.0                 2003            0
# 496           1978                    10.0                 2013            0
# 529           1990                     7.5                 2014            1
#
#      Previous_Award  Training_score_average State_Of_Origin Foreign_schooled  \
# 189               0                      80           LAGOS              Yes
# 299               0                      71             OYO              Yes
# 317               0                      66           BENUE              Yes
# 464               0                      71             EDO              Yes
# 496               0                      73         KATSINA              Yes
# 529               0                      73           DELTA               No
#
#     Marital_Status Past_Disciplinary_Action  \
# 189        Married                       No
# 299         Single                       No
# 317        Married                       No
# 464        Married                       No
# 496        Married                       No
# 529        Married                       No
#
#     Previous_IntraDepartmental_Movement No_of_previous_employers  \
# 189                                  No                        5
# 299                                  No                        1
# 317                                  No                        3
# 464                                 Yes                        0
# 496                                  No                        4
# 529                                  No                        1
#
#      Promoted_or_Not
# 189                0
# 299                0
# 317                0
# 464                0
# 496                0
# 529                0

# %% [markdown]
# #### 2. filter dataframe to include `male` employed through `Direct Internal process` with `First Degree or HND` Qualification

# %%
data_4 = data[data[['Gender', 'Division', 'Qualification']].
                isin(['Female', 'Information Technology and Solution Support', 'MSc, MBA and PhD']).all(axis=1)]

# %%
data_5 = data[data[['Gender', 'Channel_of_Recruitment', 'Qualification']].isin(
    ['Male', 'Direct Internal process', 'First Degree or HND']
).all(axis=1)]

print(data_5.shape)
data_5.head(6)
# Out:
# (7624, 19)
#      EmployeeNo                                     Division  \
# 2   YAK/S/00003               Commercial Sales and Marketing
# 4   YAK/S/00006                     Information and Strategy
# 10  YAK/S/00013               Commercial Sales and Marketing
# 21  YAK/S/00030               Commercial Sales and Marketing
# 25  YAK/S/00037  Information Technology and Solution Support
# 30  YAK/S/00048  Information Technology and Solution Support
#
#           Qualification Gender   Channel_of_Recruitment  Trainings_Attended  \
# 2   First Degree or HND   Male  Direct Internal process                   2
# 4   First Degree or HND   Male  Direct Internal process                   3
# 10  First Degree or HND   Male  Direct Internal process                   2
# 21  First Degree or HND   Male  Direct Internal process                   2
# 25  First Degree or HND   Male  Direct Internal process                   2
# 30  First Degree or HND   Male  Direct Internal process                   2
#
#     Year_of_birth  Last_performance_score  Year_of_recruitment  Targets_met  \
# 2            1987                     7.5                 2012            0
# 4            1990                     7.5                 2012            0
# 10           1972                    12.5                 2014            1
# 21           1995                     0.0                 2018            0
# 25           1988                    10.0                 2015            1
# 30           1981                     7.5                 2008            0
#
#     Previous_Award  Training_score_average State_Of_Origin Foreign_schooled  \
# 2                0                      42         KATSINA              Yes
# 4                0                      77       AKWA IBOM              Yes
# 10               0                      41           KWARA              Yes
# 21               0                      36           EKITI              Yes
# 25               0                      67           LAGOS              Yes
# 30               0                      72             IMO              Yes
#
#    Marital_Status Past_Disciplinary_Action  \
# 2         Married                       No
# 4         Married                       No
# 10        Married                       No
# 21        Married                       No
# 25        Married                       No
# 30        Married                       No
#
#    Previous_IntraDepartmental_Movement No_of_previous_employers  \
# 2                                   No                        0
# 4                                   No                        1
# 10                                 Yes                        1
# 21                                  No                        1
# 25                                  No                        1
# 30                                  No                        1
#
#     Promoted_or_Not
# 2                 0
# 4                 0
# 10                0
# 21                0
# 25                0
# 30                0

# %% [markdown]
# #### 3. filter dataframe to include those in `Customer Support and Field Operations` with `Non-University Education` and employed throgh `Direct Internal process` and are `Married`

# %%
data_6 = data[data[['Division', 'Qualification', 'Channel_of_Recruitment', 'Marital_Status']].isin(
    ['Customer Support and Field Operations', 'Non-University Education', 'Direct Internal process', 'Married']
).all(axis=1)]

print(data_6.shape)
data_6.tail(4)
# Out:
# (41, 19)
#         EmployeeNo                               Division  \
# 35739  YAK/S/51076  Customer Support and Field Operations
# 37339  YAK/S/53358  Customer Support and Field Operations
# 37660  YAK/S/53819  Customer Support and Field Operations
# 38296  YAK/S/54783  Customer Support and Field Operations
#
#                   Qualification  Gender   Channel_of_Recruitment  \
# 35739  Non-University Education  Female  Direct Internal process
# 37339  Non-University Education    Male  Direct Internal process
# 37660  Non-University Education    Male  Direct Internal process
# 38296  Non-University Education    Male  Direct Internal process
#
#        Trainings_Attended  Year_of_birth  Last_performance_score  \
# 35739                   2           1998                     7.5
# 37339                   3           1999                    10.0
# 37660                   2           1997                     0.0
# 38296                   3           1995                     7.5
#
#        Year_of_recruitment  Targets_met  Previous_Award  \
# 35739                 2017            0               0
# 37339                 2017            1               0
# 37660                 2018            0               0
# 38296                 2017            0               0
#
#        Training_score_average State_Of_Origin Foreign_schooled Marital_Status  \
# 35739                      47             OYO              Yes        Married
# 37339                      52           BENUE              Yes        Married
# 37660                      57          TARABA              Yes        Married
# 38296                      52          RIVERS              Yes        Married
#
#       Past_Disciplinary_Action Previous_IntraDepartmental_Movement  \
# 35739                       No                                  No
# 37339                       No                                  No
# 37660                       No                                 Yes
# 38296                       No                                 Yes
#
#       No_of_previous_employers  Promoted_or_Not
# 35739                        1                0
# 37339                        1                0
# 37660                        0                0
# 38296                        0                0

# %% [markdown]
# Similiarly, we can also filter our dataframe to print columns if any of the condition above is met by chaining our data to `.any` method. The code below mean filter dataframe to include those in `Customer Support and Field Operations` or with `Non-University Education` or employed through `Direct Internal process` or are `Married`

# %%
data_7 = data[data[['Division', 'Qualification', 'Channel_of_Recruitment', 'Marital_Status']].isin(
    ['Customer Support and Field Operations', 'Non-University Education', 'Direct Internal process', 'Married']
).any(axis=1)]


data_7.head(3)
# Out:
#     EmployeeNo                               Division        Qualification  \
# 0  YAK/S/00001         Commercial Sales and Marketing     MSc, MBA and PhD
# 1  YAK/S/00002  Customer Support and Field Operations  First Degree or HND
# 2  YAK/S/00003         Commercial Sales and Marketing  First Degree or HND
#
#    Gender   Channel_of_Recruitment  Trainings_Attended  Year_of_birth  \
# 0  Female  Direct Internal process                   2           1986
# 1    Male        Agency and others                   2           1991
# 2    Male  Direct Internal process                   2           1987
#
#    Last_performance_score  Year_of_recruitment  Targets_met  Previous_Award  \
# 0                    12.5                 2011            1               0
# 1                    12.5                 2015            0               0
# 2                     7.5                 2012            0               0
#
#    Training_score_average State_Of_Origin Foreign_schooled Marital_Status  \
# 0                      41         ANAMBRA               No        Married
# 1                      52         ANAMBRA              Yes        Married
# 2                      42         KATSINA              Yes        Married
#
#   Past_Disciplinary_Action Previous_IntraDepartmental_Movement  \
# 0                       No                                  No
# 1                       No                                  No
# 2                       No                                  No
#
#   No_of_previous_employers  Promoted_or_Not
# 0                        0                0
# 1                        0                0
# 2                        0                0

# %% [markdown]
# The code below means give me those employees that either have `MSc, MBA and PhD` **or** `Non-University Education` qualification

# %%
data_8 = data[data[['Qualification']].isin(
    ['MSc, MBA and PhD', 'Non-University Education']
).any(axis=1)]


data_8['Qualification'].unique()
# Out:
# array(['MSc, MBA and PhD', 'Non-University Education'], dtype=object)
