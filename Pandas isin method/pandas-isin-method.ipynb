# %%
import pandas as pd
import numpy as np

# %%
columns = ['Division', 'Qualification', 'Gender', 'Channel_of_Recruitment', 
                'Marital_Status', 'Foreign_schooled']

# %% [markdown]
# For the purpose of this tutorial we also use the columns above. Feel free to expore the entire data set

# %%
data = pd.read_csv('train.csv', usecols = columns)

data.head(5)
# Out:
#                                 Division        Qualification  Gender  \
# 0         Commercial Sales and Marketing     MSc, MBA and PhD  Female
# 1  Customer Support and Field Operations  First Degree or HND    Male
# 2         Commercial Sales and Marketing  First Degree or HND    Male
# 3         Commercial Sales and Marketing  First Degree or HND    Male
# 4               Information and Strategy  First Degree or HND    Male
#
#     Channel_of_Recruitment Foreign_schooled Marital_Status
# 0  Direct Internal process               No        Married
# 1        Agency and others              Yes        Married
# 2  Direct Internal process              Yes        Married
# 3        Agency and others              Yes         Single
# 4  Direct Internal process              Yes        Married

# %%
data.columns
# Out:
# Index(['Division', 'Qualification', 'Gender', 'Channel_of_Recruitment',
#        'Foreign_schooled', 'Marital_Status'],
#       dtype='object')

# %%
def num_unique(df, var):

    return df[var].unique()

# %% [markdown]
# ### Pandas isin Syntax
#
# **Dataframe.`isin`(values)**
#
# **Parameter**: The function takes a single value (dictionary, iterable, list or series) which runs against a vectorised boolean expression and filter the dataframe based on the values passed as arguments.
#
# **Returns**: The result is a dataframe of booleans showing whether each element in the DataFrame is contained in the values.

# %%
for var in data.columns:
    print(num_unique(data, var))
# Out:
# ['Commercial Sales and Marketing' 'Customer Support and Field Operations'
#  'Information and Strategy' 'Information Technology and Solution Support'
#  'Sourcing and Purchasing' 'Business Finance Operations'
#  'People/HR Management' 'Research and Innovation'
#  'Regulatory and Legal services']
# ['MSc, MBA and PhD' 'First Degree or HND' nan 'Non-University Education']
# ['Female' 'Male']
# ['Direct Internal process' 'Agency and others'
#  'Referral and Special candidates']
# ['No' 'Yes']
# ['Married' 'Single' 'Not_Sure']

# %% [markdown]
# ### Filtering a Single Column with Pandas Isin
#
# 1. Filter dataframe to get only those with `'MSc, MBA and PhD` qualification
# 2. Filter dataframe to get only those employed through `Referral and Special candidates`
# 3. Filter dataframe to get only those in `Customer Support and Field Operations` division

# %% [markdown]
# #### 1. Filter dataframe to get only those with `MBA and PhD` qualification

# %%
data_1 = data[data['Qualification'].isin(['MSc, MBA and PhD'])]

data_1
# Out:
#                                           Division     Qualification  Gender  \
# 0                   Commercial Sales and Marketing  MSc, MBA and PhD  Female
# 6            Customer Support and Field Operations  MSc, MBA and PhD    Male
# 8                   Commercial Sales and Marketing  MSc, MBA and PhD    Male
# 11     Information Technology and Solution Support  MSc, MBA and PhD    Male
# 18                     Business Finance Operations  MSc, MBA and PhD    Male
# ...                                            ...               ...     ...
# 38287  Information Technology and Solution Support  MSc, MBA and PhD  Female
# 38300               Commercial Sales and Marketing  MSc, MBA and PhD    Male
# 38304                      Sourcing and Purchasing  MSc, MBA and PhD    Male
# 38305               Commercial Sales and Marketing  MSc, MBA and PhD  Female
# 38308        Customer Support and Field Operations  MSc, MBA and PhD  Female
#
#         Channel_of_Recruitment Foreign_schooled Marital_Status
# 0      Direct Internal process               No        Married
# 6      Direct Internal process               No         Single
# 8      Direct Internal process              Yes        Married
# 11           Agency and others              Yes        Married
# 18     Direct Internal process              Yes         Single
# ...                        ...              ...            ...
# 38287  Direct Internal process              Yes         Single
# 38300        Agency and others              Yes         Single
# 38304        Agency and others              Yes        Married
# 38305        Agency and others              Yes        Married
# 38308        Agency and others              Yes        Married
#
# [10469 rows x 6 columns]

# %% [markdown]
# #### 2. Filter dataframe to get only those employed through `Referral and Special candidates`

# %%
data_2 = data[data['Channel_of_Recruitment'].isin(['Referral and Special candidates'])]

data_2
# Out:
#                                           Division        Qualification  \
# 53     Information Technology and Solution Support  First Degree or HND
# 77                  Commercial Sales and Marketing  First Degree or HND
# 200    Information Technology and Solution Support  First Degree or HND
# 221                        Sourcing and Purchasing  First Degree or HND
# 278          Customer Support and Field Operations     MSc, MBA and PhD
# ...                                            ...                  ...
# 38149  Information Technology and Solution Support  First Degree or HND
# 38172                         People/HR Management  First Degree or HND
# 38186  Information Technology and Solution Support  First Degree or HND
# 38190        Customer Support and Field Operations  First Degree or HND
# 38260  Information Technology and Solution Support     MSc, MBA and PhD
#
#        Gender           Channel_of_Recruitment Foreign_schooled Marital_Status
# 53       Male  Referral and Special candidates              Yes        Married
# 77       Male  Referral and Special candidates              Yes        Married
# 200      Male  Referral and Special candidates              Yes         Single
# 221    Female  Referral and Special candidates              Yes        Married
# 278    Female  Referral and Special candidates              Yes        Married
# ...       ...                              ...              ...            ...
# 38149    Male  Referral and Special candidates               No         Single
# 38172    Male  Referral and Special candidates              Yes        Married
# 38186  Female  Referral and Special candidates              Yes        Married
# 38190    Male  Referral and Special candidates               No        Married
# 38260    Male  Referral and Special candidates              Yes        Married
#
# [808 rows x 6 columns]

# %% [markdown]
# #### 3. Filter dataframe to get only those in `Customer Support and Field Operations` division

# %%
data_3 = data[data['Division'].isin(['Customer Support and Field Operations'])]

data_3
# Out:
#                                     Division             Qualification  \
# 1      Customer Support and Field Operations       First Degree or HND
# 5      Customer Support and Field Operations       First Degree or HND
# 6      Customer Support and Field Operations          MSc, MBA and PhD
# 13     Customer Support and Field Operations       First Degree or HND
# 15     Customer Support and Field Operations                       NaN
# ...                                      ...                       ...
# 38288  Customer Support and Field Operations       First Degree or HND
# 38292  Customer Support and Field Operations       First Degree or HND
# 38295  Customer Support and Field Operations       First Degree or HND
# 38296  Customer Support and Field Operations  Non-University Education
# 38308  Customer Support and Field Operations          MSc, MBA and PhD
#
#        Gender   Channel_of_Recruitment Foreign_schooled Marital_Status
# 1        Male        Agency and others              Yes        Married
# 5      Female        Agency and others              Yes        Married
# 6        Male  Direct Internal process               No         Single
# 13       Male        Agency and others              Yes        Married
# 15       Male  Direct Internal process              Yes        Married
# ...       ...                      ...              ...            ...
# 38288    Male        Agency and others              Yes        Married
# 38292    Male  Direct Internal process              Yes        Married
# 38295  Female  Direct Internal process              Yes        Married
# 38296    Male  Direct Internal process              Yes        Married
# 38308  Female        Agency and others              Yes        Married
#
# [7973 rows x 6 columns]

# %% [markdown]
# ### Filtering Multiple Columns with Pandas Isin
#
# In this section we would like at the following used cases on filtering multiple columns with pandas isin method
#
# 1. filter dataframe to include `female` in `Information Technology and Solution Support` division with `MSc MBA and PhD` Qualification
# 2. filter dataframe to include `male` employed through `Direct Internal process` with `First Degree or HND` Qualification
# 3. filter dataframe to include those in `Customer Support and Field Operations` with `Non-University Education` and employed throgh `Direct Internal process` and are `married`

# %% [markdown]
# #### 1. filter dataframe to include `female` in `Information Technology and Solution Support division` with `MSc MBA and PhD` Qualification

# %%
data_4 = data[data[['Gender', 'Division', 'Qualification']].
                isin(['Female', 'Information Technology and Solution Support', 'MSc, MBA and PhD']).all(axis=1)]

# %%
data_4.head(6)
# Out:
#                                         Division     Qualification  Gender  \
# 189  Information Technology and Solution Support  MSc, MBA and PhD  Female
# 299  Information Technology and Solution Support  MSc, MBA and PhD  Female
# 317  Information Technology and Solution Support  MSc, MBA and PhD  Female
# 464  Information Technology and Solution Support  MSc, MBA and PhD  Female
# 496  Information Technology and Solution Support  MSc, MBA and PhD  Female
# 529  Information Technology and Solution Support  MSc, MBA and PhD  Female
#
#       Channel_of_Recruitment Foreign_schooled Marital_Status
# 189        Agency and others              Yes        Married
# 299  Direct Internal process              Yes         Single
# 317  Direct Internal process              Yes        Married
# 464  Direct Internal process              Yes        Married
# 496        Agency and others              Yes        Married
# 529        Agency and others               No        Married

# %% [markdown]
# #### 2. filter dataframe to include `male` employed through `Direct Internal process` with `First Degree or HND` Qualification

# %%
data_4 = data[data[['Gender', 'Division', 'Qualification']].
                isin(['Female', 'Information Technology and Solution Support', 'MSc, MBA and PhD']).all(axis=1)]

# %%
data_5 = data[data[['Gender', 'Channel_of_Recruitment', 'Qualification']].isin(
    ['Male', 'Direct Internal process', 'First Degree or HND']
).all(axis=1)]

print(data_5.shape)
data_5.head(6)
# Out:
# (7624, 6)
#                                        Division        Qualification Gender  \
# 2                Commercial Sales and Marketing  First Degree or HND   Male
# 4                      Information and Strategy  First Degree or HND   Male
# 10               Commercial Sales and Marketing  First Degree or HND   Male
# 21               Commercial Sales and Marketing  First Degree or HND   Male
# 25  Information Technology and Solution Support  First Degree or HND   Male
# 30  Information Technology and Solution Support  First Degree or HND   Male
#
#      Channel_of_Recruitment Foreign_schooled Marital_Status
# 2   Direct Internal process              Yes        Married
# 4   Direct Internal process              Yes        Married
# 10  Direct Internal process              Yes        Married
# 21  Direct Internal process              Yes        Married
# 25  Direct Internal process              Yes        Married
# 30  Direct Internal process              Yes        Married

# %% [markdown]
# #### 3. filter dataframe to include those in `Customer Support and Field Operations` with `Non-University Education` and employed throgh `Direct Internal process` and are `Married`

# %%
data_6 = data[data[['Division', 'Qualification', 'Channel_of_Recruitment', 'Marital_Status']].isin(
    ['Customer Support and Field Operations', 'Non-University Education', 'Direct Internal process', 'Married']
).all(axis=1)]

print(data_6.shape)
data_6.tail(4)
# Out:
# (41, 6)
#                                     Division             Qualification  \
# 35739  Customer Support and Field Operations  Non-University Education
# 37339  Customer Support and Field Operations  Non-University Education
# 37660  Customer Support and Field Operations  Non-University Education
# 38296  Customer Support and Field Operations  Non-University Education
#
#        Gender   Channel_of_Recruitment Foreign_schooled Marital_Status
# 35739  Female  Direct Internal process              Yes        Married
# 37339    Male  Direct Internal process              Yes        Married
# 37660    Male  Direct Internal process              Yes        Married
# 38296    Male  Direct Internal process              Yes        Married

# %% [markdown]
# Similiarly, we can also filter our dataframe to print columns if any of the condition above is met by chaining our data to `.any` method. The code below mean filter dataframe to include those in `Customer Support and Field Operations` or with `Non-University Education` or employed through `Direct Internal process` or are `Married`

# %%
data_7 = data[data[['Division', 'Qualification', 'Channel_of_Recruitment', 'Marital_Status']].isin(
    ['Customer Support and Field Operations', 'Non-University Education', 'Direct Internal process', 'Married']
).any(axis=1)]


data_7.head(3)
# Out:
#                                 Division        Qualification  Gender  \
# 0         Commercial Sales and Marketing     MSc, MBA and PhD  Female
# 1  Customer Support and Field Operations  First Degree or HND    Male
# 2         Commercial Sales and Marketing  First Degree or HND    Male
#
#     Channel_of_Recruitment Foreign_schooled Marital_Status
# 0  Direct Internal process               No        Married
# 1        Agency and others              Yes        Married
# 2  Direct Internal process              Yes        Married

# %% [markdown]
# The code below means give me those employees that either have `MSc, MBA and PhD` **or** `Non-University Education` qualification

# %%
data_8 = data[data[['Qualification', 'Marital_Status']].isin(
    ['MSc, MBA and PhD', 'Non-University Education']
).any(axis=1)]


data_8.head(3)
# Out:
#                                 Division     Qualification  Gender  \
# 0         Commercial Sales and Marketing  MSc, MBA and PhD  Female
# 6  Customer Support and Field Operations  MSc, MBA and PhD    Male
# 8         Commercial Sales and Marketing  MSc, MBA and PhD    Male
#
#     Channel_of_Recruitment Foreign_schooled Marital_Status
# 0  Direct Internal process               No        Married
# 6  Direct Internal process               No         Single
# 8  Direct Internal process              Yes        Married

# %%
data_8
# Out:
#                                           Division             Qualification  \
# 0                   Commercial Sales and Marketing          MSc, MBA and PhD
# 6            Customer Support and Field Operations          MSc, MBA and PhD
# 8                   Commercial Sales and Marketing          MSc, MBA and PhD
# 11     Information Technology and Solution Support          MSc, MBA and PhD
# 18                     Business Finance Operations          MSc, MBA and PhD
# ...                                            ...                       ...
# 38296        Customer Support and Field Operations  Non-University Education
# 38300               Commercial Sales and Marketing          MSc, MBA and PhD
# 38304                      Sourcing and Purchasing          MSc, MBA and PhD
# 38305               Commercial Sales and Marketing          MSc, MBA and PhD
# 38308        Customer Support and Field Operations          MSc, MBA and PhD
#
#        Gender   Channel_of_Recruitment Foreign_schooled Marital_Status
# 0      Female  Direct Internal process               No        Married
# 6        Male  Direct Internal process               No         Single
# 8        Male  Direct Internal process              Yes        Married
# 11       Male        Agency and others              Yes        Married
# 18       Male  Direct Internal process              Yes         Single
# ...       ...                      ...              ...            ...
# 38296    Male  Direct Internal process              Yes        Married
# 38300    Male        Agency and others              Yes         Single
# 38304    Male        Agency and others              Yes        Married
# 38305  Female        Agency and others              Yes        Married
# 38308  Female        Agency and others              Yes        Married
#
# [11055 rows x 6 columns]

# %% [markdown]
# ### Filtering Dataframe using Pandas Isin **Not** Matching Condition
#
# We can use pandas unary operation (`~`) to perform `NOT IN` selection
#
# You can learn more about python unary operator [here](https://orclqa.com/python-unary-operator/#:~:text=A%20unary%20operator%20is%20an,preceded%20by%20the%20unary%20operator.)

# %%
# select employees that are not in Commercial Sales and Marketing or Research and Innovation
# that is, select all employees except those in Research and Innovation or Commercial Sales and Marketing division
data_9 = data[~data['Division'].isin(['Commercial Sales and Marketing', 'Research and Innovation'])]

data_9
# Out:
#                                           Division        Qualification  \
# 1            Customer Support and Field Operations  First Degree or HND
# 4                         Information and Strategy  First Degree or HND
# 5            Customer Support and Field Operations  First Degree or HND
# 6            Customer Support and Field Operations     MSc, MBA and PhD
# 7                         Information and Strategy  First Degree or HND
# ...                                            ...                  ...
# 38306                         People/HR Management  First Degree or HND
# 38307  Information Technology and Solution Support  First Degree or HND
# 38308        Customer Support and Field Operations     MSc, MBA and PhD
# 38309                     Information and Strategy  First Degree or HND
# 38311                         People/HR Management  First Degree or HND
#
#        Gender   Channel_of_Recruitment Foreign_schooled Marital_Status
# 1        Male        Agency and others              Yes        Married
# 4        Male  Direct Internal process              Yes        Married
# 5      Female        Agency and others              Yes        Married
# 6        Male  Direct Internal process               No         Single
# 7        Male        Agency and others              Yes        Married
# ...       ...                      ...              ...            ...
# 38306    Male        Agency and others              Yes        Married
# 38307  Female  Direct Internal process              Yes        Married
# 38308  Female        Agency and others              Yes        Married
# 38309    Male        Agency and others               No        Married
# 38311    Male        Agency and others              Yes         Single
#
# [25921 rows x 6 columns]

# %%
# get all employee except those in Customer Support and Field Operations
# and those that have not had foreign education

data_10 = data[~data[['Division', 'Foreign_schooled']].isin(['Customer Support and Field Operations', 'No']).any(axis = 1)]

data_10
# Out:
#                                           Division        Qualification  \
# 2                   Commercial Sales and Marketing  First Degree or HND
# 3                   Commercial Sales and Marketing  First Degree or HND
# 4                         Information and Strategy  First Degree or HND
# 7                         Information and Strategy  First Degree or HND
# 8                   Commercial Sales and Marketing     MSc, MBA and PhD
# ...                                            ...                  ...
# 38305               Commercial Sales and Marketing     MSc, MBA and PhD
# 38306                         People/HR Management  First Degree or HND
# 38307  Information Technology and Solution Support  First Degree or HND
# 38310               Commercial Sales and Marketing                  NaN
# 38311                         People/HR Management  First Degree or HND
#
#        Gender   Channel_of_Recruitment Foreign_schooled Marital_Status
# 2        Male  Direct Internal process              Yes        Married
# 3        Male        Agency and others              Yes         Single
# 4        Male  Direct Internal process              Yes        Married
# 7        Male        Agency and others              Yes        Married
# 8        Male  Direct Internal process              Yes        Married
# ...       ...                      ...              ...            ...
# 38305  Female        Agency and others              Yes        Married
# 38306    Male        Agency and others              Yes        Married
# 38307  Female  Direct Internal process              Yes        Married
# 38310    Male  Direct Internal process              Yes        Married
# 38311    Male        Agency and others              Yes         Single
#
# [27746 rows x 6 columns]

# %%
data_10['Division'].unique()
# Out:
# array(['Commercial Sales and Marketing', 'Information and Strategy',
#        'Information Technology and Solution Support',
#        'Sourcing and Purchasing', 'Business Finance Operations',
#        'Research and Innovation', 'Regulatory and Legal services',
#        'People/HR Management'], dtype=object)

# %%
col_missing = [
    var for var in data.columns if data[var].isnull().sum() > 0
]

col_missing
# Out:
# ['Qualification']

# %%
print(data['Qualification'].isnull().sum())
print(data['Qualification'].unique())
# Out:
# 1679
# ['MSc, MBA and PhD' 'First Degree or HND' nan 'Non-University Education']
